# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta

# %%
# List of 10 tickers from the Russell 2000
tickers = ['BXP', 'CDNS',  'DXCM', 'EPAM', 'EVRG', 'EXPD', 'FFIV', 'FTNT', 'GILD']

data = {}
for ticker in tickers:
    df = yf.download(ticker, start="2021-01-01")
    data[ticker] = df
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Running the Builtin CommonStrategy as mentioned above
df.ta.strategy(ta.CommonStrategy)

# %%
df = data['BXP']

# %%
import vectorbt as vbt

# %%
df["GC"] = df.ta.sma(50, append=True) > df.ta.sma(200, append=True)
# Create boolean Signals(TS_Entries, TS_Exits) for vectorbt
golden = df.ta.tsignals(df.GC, asbool=True, append=True)

# %%
df
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2021-01-04  95.300003  95.959999  90.750000  90.820000  77.088509  1240100
# 2021-01-05  91.320000  92.820000  89.989998  90.089996  76.468887  1200500
# 2021-01-06  90.660004  92.769997  89.760002  91.419998  77.597801  1960000
# 2021-01-07  91.449997  91.449997  89.379997  90.250000  76.604698  1179600
# 2021-01-08  90.050003  90.879997  89.139999  90.040001  76.426453  1123300
# ...               ...        ...        ...        ...        ...      ...
# 2024-05-30  57.590000  58.220001  57.240002  58.189999  58.189999  1213200
# 2024-05-31  58.860001  60.750000  58.270000  60.669998  60.669998  2268300
# 2024-06-03  60.790001  60.939999  59.610001  60.040001  60.040001   975300
# 2024-06-04  59.639999  60.820000  59.610001  59.950001  59.950001   942200
# 2024-06-05  59.959999  60.550098  59.459999  59.720001  59.720001   829211
#
# ...

# %%
# Create the Signals Portfolio
pf = vbt.Portfolio.from_signals(df.Close, entries=golden.TS_Entries, exits=golden.TS_Exits, freq="D", init_cash=100_000, fees=0.0025, slippage=0.0025)

# %%
# Print Portfolio Stats and Return Stats
print(pf.stats())
print(pf.returns_stats())
# Out:
# Start                         2021-01-04 00:00:00
# End                           2024-06-05 00:00:00
# Period                          861 days 00:00:00
# Start Value                              100000.0
# End Value                            59719.082802
# Total Return [%]                       -40.280917
# Benchmark Return [%]                   -34.243557
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                       1161.094396
# Max Drawdown [%]                        50.617401
# Max Drawdown Duration           549 days 00:00:00
# Total Trades                                    3
# Total Closed Trades                             3
# Total Open Trades                               0
# Open Trade PnL                                0.0
# Win Rate [%]                                  0.0
# Best Trade [%]                         -14.217274
# Worst Trade [%]                        -17.222627
# Avg Winning Trade [%]                         NaN
# ...

# %%
# ?vbt.Portfolio.from_signals
# Out:
# Signature:
# vbt.Portfolio.from_signals(
#     close: Union[str, float, int, complex, bool, object, numpy.generic, Sequence[Union[str, float, int, complex, bool, object, numpy.generic]], Sequence[Sequence[Any]], vectorbt._typing.SupportsArray, numpy.ndarray, pandas.core.indexes.base.Index, pandas.core.series.Series, pandas.core.frame.DataFrame],
#     entries: Union[str, float, int, complex, bool, object, numpy.generic, Sequence[Union[str, float, int, complex, bool, object, numpy.generic]], Sequence[Sequence[Any]], vectorbt._typing.SupportsArray, numpy.ndarray, pandas.core.indexes.base.Index, pandas.core.series.Series, pandas.core.frame.DataFrame, NoneType] = None,
#     exits: Union[str, float, int, complex, bool, object, numpy.generic, Sequence[Union[str, float, int, complex, bool, object, numpy.generic]], Sequence[Sequence[Any]], vectorbt._typing.SupportsArray, numpy.ndarray, pandas.core.indexes.base.Index, pandas.core.series.Series, pandas.core.frame.DataFrame, NoneType] = None,
# ...

# %%
# ?vbt.Portfolio.from_orders
# Out:
# Signature:
# vbt.Portfolio.from_orders(
#     close: Union[str, float, int, complex, bool, object, numpy.generic, Sequence[Union[str, float, int, complex, bool, object, numpy.generic]], Sequence[Sequence[Any]], vectorbt._typing.SupportsArray, numpy.ndarray, pandas.core.indexes.base.Index, pandas.core.series.Series, pandas.core.frame.DataFrame],
#     size: Union[str, float, int, complex, bool, object, numpy.generic, Sequence[Union[str, float, int, complex, bool, object, numpy.generic]], Sequence[Sequence[Any]], vectorbt._typing.SupportsArray, numpy.ndarray, pandas.core.indexes.base.Index, pandas.core.series.Series, pandas.core.frame.DataFrame, NoneType] = None,
#     size_type: Union[str, float, int, complex, bool, object, numpy.generic, Sequence[Union[str, float, int, complex, bool, object, numpy.generic]], Sequence[Sequence[Any]], vectorbt._typing.SupportsArray, numpy.ndarray, pandas.core.indexes.base.Index, pandas.core.series.Series, pandas.core.frame.DataFrame, NoneType] = None,
# ...

# %%
# Out:
# 'lag_1'
